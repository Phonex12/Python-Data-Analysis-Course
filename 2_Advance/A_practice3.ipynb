# %% [markdown]
# ## Index Managment in Pandas

# %% [markdown]
# Index management in Pandas involves various operations related to accessing, setting, and manipulating the row labels of a DataFrame or Series. The index serves as a crucial component for efficient data retrieval, alignment, and manipulation.

# %%
import pandas as pd
df = pd.read_csv('D:\\python Programming\\DataSets\\data_jobs.csv')

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.index.name = 'job_id'
df
# Out:
# 'job_id'

# %%
median_pivot = df.pivot_table(values= 'salary_year_avg',index = 'job_title_short',aggfunc='median')
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
median_pivot.index.name
# Out:
# 'job_title_short'

# %% [markdown]
# **reset_index() : this method is used to bring back the old type of index i.e 0,1,2,3,4,5......**

# %%
# To make the changes permanant to the table we can use the inplace=True value to it
median_pivot.reset_index(inplace = True)
median_pivot
# Out:
#              job_title_short  salary_year_avg
# 0           Business Analyst          85000.0
# 1             Cloud Engineer          90000.0
# 2               Data Analyst          90000.0
# 3              Data Engineer         125000.0
# 4             Data Scientist         127500.0
# 5  Machine Learning Engineer         106415.0
# 6        Senior Data Analyst         111175.0
# 7       Senior Data Engineer         147500.0
# 8      Senior Data Scientist         155500.0
# 9          Software Engineer          99150.0

# %%
df.reset_index(inplace=True)

# %% [markdown]
# **set_index() : This method is used to set a unique colunm of the row index**

# %%
df_united_state = df[df['job_country'] == 'United States']
df_united_state.sample(5)
# Out:
#         job_id        job_title_short                   job_title  \
# 732506  732506           Data Analyst                Data Analyst
# 324324  324324           Data Analyst        RA/QA Data Analytics
# 449117  449117   Senior Data Engineer        Senior Data Engineer
# 477205  477205  Senior Data Scientist  URBN Senior Data Scientist
# 286842  286842          Data Engineer           Sr. Data Engineer
#
#             job_location               job_via job_schedule_type  \
# 732506        Austin, TX          via LinkedIn         Full-time
# 324324     Sunnyvale, CA              via Dice        Contractor
# 449117         Louisiana          via LinkedIn        Contractor
# 477205  Philadelphia, PA  via Big Country Jobs         Full-time
# 286842      Longview, TX             via BeBee         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 732506               False       Texas, United States 2023-11-09 21:01:11
# 324324               False  California, United States 2023-07-06 17:01:07
# 449117               False    New York, United States 2023-05-26 14:06:18
# 477205               False    New York, United States 2023-01-07 14:02:05
# 286842               False       Texas, United States 2023-11-28 17:07:28
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 732506                  False                 False  United States
# 324324                  False                 False  United States
# 449117                  False                 False  United States
# 477205                  False                 False  United States
# 286842                  False                  True  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 732506         NaN              NaN              NaN
# 324324        hour              NaN             55.0
# 449117         NaN              NaN              NaN
# 477205         NaN              NaN              NaN
# 286842         NaN              NaN              NaN
#
#                                              company_name  \
# 732506                                            TextNow
# 324324                                 Mumba Technologies
# 449117                            Vuesol Technologies Inc
# 477205  URBN (Urban Outfitters, Anthropologie Group, F...
# 286842                                  Jobs for Humanity
#
#                                                job_skills  \
# 732506            ['sql', 'snowflake', 'tableau', 'flow']
# 324324              ['sql', 'tableau', 'power bi', 'sap']
# 449117  ['sql', 'scala', 'sql server', 'azure', 'datab...
# 477205  ['sql', 'python', 'jupyter', 'tensorflow', 'py...
# 286842  ['scala', 'nosql', 'python', 'sql', 'java', 'm...
#
#                                           job_type_skills
# 732506  {'analyst_tools': ['tableau'], 'cloud': ['snow...
# 324324  {'analyst_tools': ['tableau', 'power bi', 'sap...
# 449117  {'cloud': ['azure', 'databricks'], 'databases'...
# 477205  {'libraries': ['jupyter', 'tensorflow', 'pytor...
# 286842  {'cloud': ['aws', 'azure', 'redshift', 'snowfl...

# %%
df_united_state.set_index('job_id')
df_united_state.head(5)
# Out:
#    job_id       job_title_short  \
# 0       0  Senior Data Engineer
# 3       3         Data Engineer
# 5       5         Data Engineer
# 6       6  Senior Data Engineer
# 9       9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                  GCP Data Engineer         Anywhere
# 6                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 3  via Diversity.com                 Full-time               False
# 5   via ZipRecruiter  Contractor and Temp work                True
# 6       via LinkedIn                 Full-time               False
# 9   via ZipRecruiter                 Full-time                True
#
#            search_location     job_posted_date  job_no_degree_mention  \
# 0     Texas, United States 2023-06-16 13:44:15                  False
# 3     Texas, United States 2023-07-04 13:01:41                   True
# 5                  Georgia 2023-11-07 14:01:59                  False
# 6   Florida, United States 2023-03-27 13:18:18                  False
# 9  New York, United States 2023-04-23 13:02:57                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States         NaN              NaN
# 3                 False  United States         NaN              NaN
# 5                 False  United States         NaN              NaN
# 6                 False  United States         NaN              NaN
# 9                 False  United States         NaN              NaN
#
#    salary_hour_avg                   company_name  \
# 0              NaN           Boehringer Ingelheim
# 3              NaN   Southwest Research Institute
# 5              NaN                smart folks inc
# 6              NaN  Miracle Software Systems, Inc
# 9              NaN     Radwell International, LLC
#
#                                           job_skills  \
# 0                                                NaN
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                           ['python', 'sql', 'gcp']
# 6  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 0                                                NaN
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5  {'cloud': ['gcp'], 'programming': ['python', '...
# 6  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
median_pivot.set_index('job_title_short' ,inplace=True)

# %%
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %% [markdown]
# **sort_index() : This method is not that frequently directly used in dataset but it can be used in grouping values or pivot tables to sort the index data**

# %%
median_pivot.sort_values(by = 'salary_year_avg', ascending=False)
# Out:
#                            salary_year_avg
# job_title_short
# Senior Data Scientist             155500.0
# Senior Data Engineer              147500.0
# Data Scientist                    127500.0
# Data Engineer                     125000.0
# Senior Data Analyst               111175.0
# Machine Learning Engineer         106415.0
# Software Engineer                  99150.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Business Analyst                   85000.0
